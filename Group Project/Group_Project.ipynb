# %%
import pandas as pd
import pyarrow.parquet as pq
import os
import tqdm

# %%
result = pd.DataFrame()
file_lst = []
for root, dirs, files in os.walk('data/'):
    for file_name in files:
        if file_name.endswith('.parquet'):
            # file_lst.append(file_name)
            path = 'data/raw/' + file_name
            data = pq.read_table(path).to_pandas()
            result = pd.concat([result, data])
# result.to_parquet('data/green_sum.parquet', index=False)

# %%
data = pq.read_table('data/green_sum.parquet').to_pandas()
data.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
df = data[(data['lpep_pickup_datetime'] >= "2022")
          & ("2023-08" >= data['lpep_pickup_datetime'])].reset_index(drop=True)
# df.to_parquet('data/green_sum_2201-2307.parquet', index=False)

# %%
df = pq.read_table('data/green_sum_2201-2307.parquet').to_pandas()
df
# Out:
#          VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0               2  2022-09-01 00:45:23   2022-09-01 00:52:39
# 1               2  2022-09-01 00:40:58   2022-09-01 01:11:42
# 2               2  2022-09-01 00:03:27   2022-09-01 00:08:31
# 3               2  2022-09-01 00:31:17   2022-09-01 00:35:20
# 4               2  2022-08-31 23:58:32   2022-09-01 00:15:52
# ...           ...                  ...                   ...
# 1306904         2  2023-03-31 23:33:00   2023-03-31 23:45:00
# 1306905         2  2023-03-31 23:27:00   2023-03-31 23:53:00
# 1306906         2  2023-03-31 23:09:00   2023-03-31 23:40:00
# 1306907         2  2023-03-31 23:39:00   2023-04-01 00:01:00
# 1306908         2  2023-03-31 23:38:00   2023-03-31 23:53:00
#
#         store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                        N         1.0            74            42
# 1                        N         5.0            93            79
# ...

# %%
df.drop(columns=['ehail_fee'])
df.isnull().sum()
# Out:
# VendorID                       0
# lpep_pickup_datetime           0
# lpep_dropoff_datetime          0
# store_and_fwd_flag        123159
# RatecodeID                123159
# PULocationID                   0
# DOLocationID                   0
# passenger_count           123159
# trip_distance                  0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# ehail_fee                1306909
# improvement_surcharge          0
# total_amount                   0
# payment_type              123159
# trip_type                 123206
# congestion_surcharge      123159
# dtype: int64
